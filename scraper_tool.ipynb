# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Load the Excel file
input_file_path = 'Input.xlsx'  # Update this path if necessary
data = pd.read_excel(input_file_path)

# %%
data
# Out:
#              URL_ID                                                URL
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 2 columns]

# %%
def extract_text_from_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            paragraphs = soup.find_all('p')
            text = '\n'.join(p.get_text() for p in paragraphs)
            return text
        else:
            return None
    except Exception as e:
        print(f"Error fetching URL {url}: {e}")
        return None

# %%
def save_text_to_file(text, file_name):
    with open(f"{file_name}.txt", 'w', encoding='utf-8') as file:
        file.write(text)

# %%
for _, row in data.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    extracted_text = extract_text_from_url(url)
    if extracted_text:
        save_text_to_file(extracted_text, url_id)
        print(f"Text extracted and saved for {url_id}")
    else:
        print(f"Failed to extract text for {url_id}")
# Out:
# Text extracted and saved for blackassign0001
# Text extracted and saved for blackassign0002
# Text extracted and saved for blackassign0003
# Text extracted and saved for blackassign0004
# Text extracted and saved for blackassign0005
# Text extracted and saved for blackassign0006
# Text extracted and saved for blackassign0007
# Text extracted and saved for blackassign0008
# Text extracted and saved for blackassign0009
# Text extracted and saved for blackassign0010
# Text extracted and saved for blackassign0011
# Text extracted and saved for blackassign0012
# Text extracted and saved for blackassign0013
# Text extracted and saved for blackassign0014
# Text extracted and saved for blackassign0015
# Text extracted and saved for blackassign0016
# Text extracted and saved for blackassign0017
# Text extracted and saved for blackassign0018
# Text extracted and saved for blackassign0019
# Text extracted and saved for blackassign0020
# Text extracted and saved for blackassign0021
# Text extracted and saved for blackassign0022
# Text extracted and saved for blackassign0023
# Text extracted and saved for blackassign0024
# Text extracted and saved for blackassign0025
# Text extracted and saved for blackassign0026
# Text extracted and saved for blackassign0027
# Text extracted and saved for blackassign0028
# Text extracted and saved for blackassign0029
# Text extracted and saved for blackassign0030
# Text extracted and saved for blackassign0031
# Text extracted and saved for blackassign0032
# Text extracted and saved for blackassign0033
# Text extracted and saved for blackassign0034
# Text extracted and saved for blackassign0035
# Failed to extract text for blackassign0036
# Text extracted and saved for blackassign0037
# Text extracted and saved for blackassign0038
# Text extracted and saved for blackassign0039
# Text extracted and saved for blackassign0040
# Text extracted and saved for blackassign0041
# Text extracted and saved for blackassign0042
# Text extracted and saved for blackassign0043
# Text extracted and saved for blackassign0044
# Text extracted and saved for blackassign0045
# Text extracted and saved for blackassign0046
# Text extracted and saved for blackassign0047
# Text extracted and saved for blackassign0048
# Failed to extract text for blackassign0049
# Text extracted and saved for blackassign0050
# Text extracted and saved for blackassign0051
# Text extracted and saved for blackassign0052
# Text extracted and saved for blackassign0053
# Text extracted and saved for blackassign0054
# Text extracted and saved for blackassign0055
# Text extracted and saved for blackassign0056
# Text extracted and saved for blackassign0057
# Text extracted and saved for blackassign0058
# Text extracted and saved for blackassign0059
# Text extracted and saved for blackassign0060
# Text extracted and saved for blackassign0061
# Text extracted and saved for blackassign0062
# Text extracted and saved for blackassign0063
# Text extracted and saved for blackassign0064
# Text extracted and saved for blackassign0065
# Text extracted and saved for blackassign0066
# Text extracted and saved for blackassign0067
# Text extracted and saved for blackassign0068
# Text extracted and saved for blackassign0069
# Text extracted and saved for blackassign0070
# Text extracted and saved for blackassign0071
# Text extracted and saved for blackassign0072
# Text extracted and saved for blackassign0073
# Text extracted and saved for blackassign0074
# Text extracted and saved for blackassign0075
# Text extracted and saved for blackassign0076
# Text extracted and saved for blackassign0077
# Text extracted and saved for blackassign0078
# Text extracted and saved for blackassign0079
# Text extracted and saved for blackassign0080
# Text extracted and saved for blackassign0081
# Text extracted and saved for blackassign0082
# Text extracted and saved for blackassign0083
# Text extracted and saved for blackassign0084
# Text extracted and saved for blackassign0085
# Text extracted and saved for blackassign0086
# Text extracted and saved for blackassign0087
# Text extracted and saved for blackassign0088
# Text extracted and saved for blackassign0089
# Text extracted and saved for blackassign0090
# Text extracted and saved for blackassign0091
# Text extracted and saved for blackassign0092
# Text extracted and saved for blackassign0093
# Text extracted and saved for blackassign0094
# Text extracted and saved for blackassign0095
# Text extracted and saved for blackassign0096
# Text extracted and saved for blackassign0097
# Text extracted and saved for blackassign0098
# Text extracted and saved for blackassign0099
# Text extracted and saved for blackassign0100
